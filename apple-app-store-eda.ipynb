# %% [markdown]
# # Complete EDA on Apple Apps store  Dataset

# %% [markdown]
# ># 2.0 `ABOUT_AUTHOR :`
# - **PROJECT** : *`APPLE APP STORE DATA`*
# - **AUTHOR_NAME**  : *`MUHMMAD BILAL RAMZAN`*
# - **CODE_SUBMISSION**  : *`21- 8 - 2024`*
# - **AUTHOR_CONTACT_INFO** :
# -  [`EMAIL`](mailto:mianb0062@gmail.com)
# - [ `LINKDEN`](https://www.linkedin.com/in/bilal-ramzan/)
# - [`KAGGLE`](https://www.kaggle.com/)

# %% [markdown]
# # 2.1 `ABOUT_DATA:`
# - ***DATA***: *`APPLE_APPS_STORE_DATA `*
# - ***DATA_AGE***: *`THE DATA WAS COLLECTED IN THE MONTH OF OCTOBER 2021`*
# - [`DATA_set_link🔗`](https://www.kaggle.com/gauthamp10/apple-appstore-apps)

# %% [markdown]
# # `2.2` `Task Overview`:
# *We are going to perform an Exploratory Data Analysis (EDA) on the provided dataset. The purpose of this EDA is to help us understand the data better, which will guide us in cleaning and organizing it properly.
# As we work through the analysis, we will take notes on our observations. In the end, we will summarize our findings and draw conclusions based on what we discovered*

# %% [markdown]
# # `2.3` OBJECTIVE:
# *The main goal of this project is to analyze the dataset carefully to find important insights. We want to highlight customer behaviors and needs for developers and other key stakeholders. This information will help attract more business for their future applications*.

# %% [markdown]
# # ``2.4``*KERNEL_VERSION* : `3.12.4 `

# %% [markdown]
# # `2.5`   *IMPORT LIBARIES*

# %%
import pandas as pd # Data manipulation and analysis library.
import numpy as np # Numerical computing library.
import matplotlib .pyplot as plt# Data visualization library.
import seaborn as sns #Data visualization library.
# %matplotlib inline 
import scipy as sp #To provide a comprehensive set of numerical algorithms and tools for scientific computing in Python.

# %%
df=pd.read_csv('/kaggle/input/apple-appstore-apps/appleAppData.csv')

# %% [markdown]
#  # `2.6`  *LOAD THE CSV FILE USING PANDAS*

# %% [markdown]
# # `2.7`  *NOW SET THE MAX ROWS AND COLUMNS TO SHOW THE FULL ROWS AND COULMNS*

# %%
pd.set_option('display.max_columns',None)# DISPLAY THE MAX ROWS 
pd.set_option('display.max_rows',None)   # DISPLAY THE MAX ROWS

# %%
import warnings             
warnings.filterwarnings('ignore')  # help to ignore the warning

# %% [markdown]
# >`QUICK OVERVIEW OF THE DATA`:

# %% [markdown]
#  # `2.8` *Display the first five rows of the dataset to give a quick overview of its structure and content*

# %%
df.head(5)
# Out:
#                              App_Id                 App_Name  \
# 0               com.hkbu.arc.apaper           A+ Paper Guide
# 1               com.dmitriev.abooks                  A-Books
# 2                    no.terp.abooks                  A-books
# 3          fr.antoinettefleur.Book1              A-F Book #1
# 4  com.imonstersoft.azdictionaryios  A-Z Synonyms Dictionary
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
# 2  https://apps.apple.com/us/app/a-books/id145702...          Book
# 3  https://apps.apple.com/us/app/a-f-book-1/id500...          Book
# 4  https://apps.apple.com/us/app/a-z-synonyms-dic...     Reference
#
#   Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 0             4+  21993472.0                  8.0  2017-09-28T03:02:41Z
# ...

# %%
df.describe()
# Out:
#          Size_Bytes         Price   DeveloperId  Average_User_Rating  \
# count  1.230152e+06  1.229886e+06  1.230376e+06         1.230376e+06
# mean   7.510857e+07  5.041264e-01  1.092869e+09         1.788387e+00
# std    2.318726e+08  6.869674e+00  4.090897e+08         2.154105e+00
# min    2.762800e+04  0.000000e+00  2.816565e+08         0.000000e+00
# 25%    2.041344e+07  0.000000e+00  7.381109e+08         0.000000e+00
# 50%    4.333158e+07  0.000000e+00  1.179711e+09         0.000000e+00
# 75%    8.365466e+07  0.000000e+00  1.471960e+09         4.333330e+00
# max    7.677945e+10  9.999900e+02  1.590233e+09         5.000000e+00
#
#             Reviews  Current_Version_Score  Current_Version_Reviews
# count  1.230376e+06           1.230376e+06             1.230376e+06
# mean   8.259478e+02           1.788387e+00             8.259478e+02
# std    5.016051e+04           2.154105e+00             5.016051e+04
# min    0.000000e+00           0.000000e+00             0.000000e+00
# ...

# %% [markdown]
#  # `2.9` *NOW SEE THE  COLUMNS OF DATA*

# %%
df.columns
# Out:
# Index(['App_Id', 'App_Name', 'AppStore_Url', 'Primary_Genre', 'Content_Rating',
#        'Size_Bytes', 'Required_IOS_Version', 'Released', 'Updated', 'Version',
#        'Price', 'Currency', 'Free', 'DeveloperId', 'Developer',
#        'Developer_Url', 'Developer_Website', 'Average_User_Rating', 'Reviews',
#        'Current_Version_Score', 'Current_Version_Reviews'],
#       dtype='object')

# %% [markdown]
# # `3.0`: *NOW COUNT THE NUMBER OF COLUMNS AND ROWS*

# %%
# Count the number of columns
num_columns = df.shape[1]
print(f'Number of columns: {num_columns}')

# Count the number of rows
num_rows = df.shape[0]
print(f'Number of rows: {num_rows}')
# Out:
# Number of columns: 21
# Number of rows: 1230376

# %% [markdown]
# * THE DATA SET CONTAIN 1230276 ROWS
# * AND 21 COLUMNS

# %% [markdown]
#  # `3.1` *NOW CHECK THE DATATYPES OF COLUMNS*

# %%
df.dtypes#Displays the data types of each column, helping to identify numerical and categorical variables.
# Out:
# App_Id                      object
# App_Name                    object
# AppStore_Url                object
# Primary_Genre               object
# Content_Rating              object
# Size_Bytes                 float64
# Required_IOS_Version        object
# Released                    object
# Updated                     object
# Version                     object
# Price                      float64
# Currency                    object
# Free                          bool
# DeveloperId                  int64
# Developer                   object
# Developer_Url               object
# Developer_Website           object
# Average_User_Rating        float64
# Reviews                      int64
# Current_Version_Score      float64
# Current_Version_Reviews      int64
# dtype: object

# %% [markdown]
# *we have 15 categorical columns and 7  numerical columns  in this dataset*

# %% [markdown]
# `3.2`   *TO GET A SUMMARY OF DATA SET*

# %%
df.info() #Provides a concise summary of the DataFrame, including the number of non-null entries and the data types.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1230376 entries, 0 to 1230375
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   App_Id                   1230376 non-null  object
#  1   App_Name                 1230375 non-null  object
#  2   AppStore_Url             1230376 non-null  object
#  3   Primary_Genre            1230376 non-null  object
#  4   Content_Rating           1230376 non-null  object
#  5   Size_Bytes               1230152 non-null  float64
#  6   Required_IOS_Version     1230376 non-null  object
#  7   Released                 1230373 non-null  object
#  8   Updated                  1230376 non-null  object
#  9   Version                  1230376 non-null  object
#  10  Price                    1229886 non-null  float64
#  11  Currency                 1230376 non-null  object
#  12  Free                     1230376 non-null  bool
# ...

# %% [markdown]
# ***Explanation:***
# * This step helps you understand the structure of the dataset, including the number of entries, data types of each column, and any non-null values. The info() function is crucial for identifying potential issues, such as incorrect data types or columns with missing data.

# %% [markdown]
# # `3.3` *viewing the numerical columns of the dataset*

# %%
df.describe()
# Out:
#          Size_Bytes         Price   DeveloperId  Average_User_Rating  \
# count  1.230152e+06  1.229886e+06  1.230376e+06         1.230376e+06
# mean   7.510857e+07  5.041264e-01  1.092869e+09         1.788387e+00
# std    2.318726e+08  6.869674e+00  4.090897e+08         2.154105e+00
# min    2.762800e+04  0.000000e+00  2.816565e+08         0.000000e+00
# 25%    2.041344e+07  0.000000e+00  7.381109e+08         0.000000e+00
# 50%    4.333158e+07  0.000000e+00  1.179711e+09         0.000000e+00
# 75%    8.365466e+07  0.000000e+00  1.471960e+09         4.333330e+00
# max    7.677945e+10  9.999900e+02  1.590233e+09         5.000000e+00
#
#             Reviews  Current_Version_Score  Current_Version_Reviews
# count  1.230376e+06           1.230376e+06             1.230376e+06
# mean   8.259478e+02           1.788387e+00             8.259478e+02
# std    5.016051e+04           2.154105e+00             5.016051e+04
# min    0.000000e+00           0.000000e+00             0.000000e+00
# ...

# %% [markdown]
# `obeservation`:
# - we can convert size_bytes into size_mb
# - AND MAKINFG A NEW COLUMN

# %%
# making a new column called 'Size in Mb' which will have the size in MB
df['Size_Mb'] = df['Size_Bytes'].apply(lambda x: x/(1024*1024))

# %% [markdown]
# ---
# - NOW WE HAVE CONVERTED SIZE BYTES INTO SIZE IN MB AND ADDED IT INTO THE DATASET
# ---

# %%
df.describe()
# Out:
#          Size_Bytes         Price   DeveloperId  Average_User_Rating  \
# count  1.230152e+06  1.229886e+06  1.230376e+06         1.230376e+06
# mean   7.510857e+07  5.041264e-01  1.092869e+09         1.788387e+00
# std    2.318726e+08  6.869674e+00  4.090897e+08         2.154105e+00
# min    2.762800e+04  0.000000e+00  2.816565e+08         0.000000e+00
# 25%    2.041344e+07  0.000000e+00  7.381109e+08         0.000000e+00
# 50%    4.333158e+07  0.000000e+00  1.179711e+09         0.000000e+00
# 75%    8.365466e+07  0.000000e+00  1.471960e+09         4.333330e+00
# max    7.677945e+10  9.999900e+02  1.590233e+09         5.000000e+00
#
#             Reviews  Current_Version_Score  Current_Version_Reviews  \
# count  1.230376e+06           1.230376e+06             1.230376e+06
# mean   8.259478e+02           1.788387e+00             8.259478e+02
# std    5.016051e+04           2.154105e+00             5.016051e+04
# min    0.000000e+00           0.000000e+00             0.000000e+00
# ...

# %% [markdown]
# ## FIGURE 1.1:
# ---
# - Now, we have only 8 columns as numeric data type.
# - We can observe their descriptive statistics. and make tons of observations as per our hypotheses.
# - Similarly, we can observe the other columns as well.
# But even before that we have to think about the missing values in the dataset.
# ---

# %% [markdown]
# ## **3.4. Dealing with the missing values**
# Dealing with the missing values is one of the most important part of the data wrangling process, we must deal with the missing values in order to get the correct insights from the data.

# %% [markdown]
# - > *lets have a look on missing values*

# %%
df.isnull().sum() # this will show the missing values in each column
# Out:
# App_Id                          0
# App_Name                        1
# AppStore_Url                    0
# Primary_Genre                   0
# Content_Rating                  0
# Size_Bytes                    224
# Required_IOS_Version            0
# Released                        3
# Updated                         0
# Version                         0
# Price                         490
# Currency                        0
# Free                            0
# DeveloperId                     0
# Developer                       0
# Developer_Url                1109
# Developer_Website          643988
# Average_User_Rating             0
# Reviews                         0
# Current_Version_Score           0
# Current_Version_Reviews         0
# Size_Mb                       224
# dtype: int64

# %% [markdown]
# ---
# >` Reviewing The Missing Values`:\
# `High Missing Values`: 'Developer_Website' has a very high number of missing values (643,988). This could be significant if you plan to use this information for analysis.\
# `Moderate Missing Values`: 'size_bytes,'size_in_mb','Price' and 'Developer_Url' also have a considerable number of missing values (224,224,490 and 1,109, respectively).\
# `Low Missing` Values: Most other columns have few or no missing values, with 'App_Name' and 'Released' having the smallest number of missing values.
# ---

# %% [markdown]
# `3.5` *NOW CHECK THE Missing VALUES IN THE Percentage*

# %%
(df.isnull().sum()/len(df)*100).sort_values(ascending=False) # this will show the percentage of null values in each column
# Out:
# Developer_Website          52.340748
# Developer_Url               0.090135
# Price                       0.039825
# Size_Mb                     0.018206
# Size_Bytes                  0.018206
# Released                    0.000244
# App_Name                    0.000081
# DeveloperId                 0.000000
# Current_Version_Reviews     0.000000
# Current_Version_Score       0.000000
# Reviews                     0.000000
# Average_User_Rating         0.000000
# Developer                   0.000000
# App_Id                      0.000000
# Free                        0.000000
# Version                     0.000000
# Updated                     0.000000
# Required_IOS_Version        0.000000
# Content_Rating              0.000000
# Primary_Genre               0.000000
# AppStore_Url                0.000000
# Currency                    0.000000
# dtype: float64

# %% [markdown]
# ***Explanation***:\
# Understanding missing data is critical, as it can significantly impact the quality of analysis and model performance. This step provides a detailed view of how much data is missing and in which columns

# %% [markdown]
# >#  FIGURE 1.2
# `LETS MAKING THE PLOTS TO CHECK THE MISSING VALUES`:

# %% [markdown]
# # `3.6` *making  heatmap plots to see  the missing values*

# %%
# Plot heatmap of missing values
plt.figure(figsize=(12, 8))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis', yticklabels=False)
plt.title('Heatmap of Missing Values')
plt.xlabel('Columns')
plt.ylabel('Rows')
plt.show()

# %% [markdown]
# # FIGURE 1.2
# - | THESE LINE SHOW THE MISSING VALUES IN PLOTS

# %% [markdown]
# # `3.7`*making bar plot to see the missing values*

# %%
# Count missing values per column
missing_counts = df.isnull().sum()

# Plot bar chart of missing values
plt.figure(figsize=(12, 8))
missing_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Missing Values per Column')
plt.xlabel('Columns')
plt.ylabel('Number of Missing Values')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # FIGURE 1.3
# - AS YOU CAN SEEE THESE BAR SHOW  Developar_website have high missing value

# %% [markdown]
# # `3.8` *Plot Distribution of Missing Values*

# %%
# Calculate percentage of missing values
missing_percentage = (df.isnull().sum() / len(df)) * 100

# Plot bar chart of missing value percentages
plt.figure(figsize=(12, 8))
missing_percentage.plot(kind='bar', color='lightcoral')
plt.title('Percentage of Missing Values per Column')
plt.xlabel('Columns')
plt.ylabel('Percentage of Missing Values (%)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # FIGURE 1.5
# - PERCENTAGE OF DEVELOPAR_WEBSITE HAS HIGH MISSING VALUE

# %% [markdown]
# # `3.9` Handling Missing Values

# %% [markdown]
# ---
# - Dropping Missing Values: Sometimes, it's best to drop rows or columns with a significant amount of missing data, especially if they provide little value.
# - Filling Missing Values: In other cases, you might fill missing values using strategies like mean, median, mode.
#
# ---

# %%
# length before removing null values
print(f"Length of the dataframe before removing null values: {len(df)}")
# Out:
# Length of the dataframe before removing null values: 1230376

# %%
df.dropna(subset=['Developer_Website'], inplace=True)

# %% [markdown]
# - Before going ahead, let's remove the rows with missing values in the `App_Name`, `Developer_Url`, `Released`,   columns, as they are very less in number and will not affect our analysis.

# %%
df.dropna(subset=['App_Name','Developer_Url','Released'], inplace=True)

# %%
# length after removing null values
print(f"Length after removing null values: {len(df)}")
# Out:
# Length after removing null values: 586012

# %% [markdown]
# ---
# - lets check on missing value

# %%
df.isnull().sum()
# Out:
# App_Id                       0
# App_Name                     0
# AppStore_Url                 0
# Primary_Genre                0
# Content_Rating               0
# Size_Bytes                 170
# Required_IOS_Version         0
# Released                     0
# Updated                      0
# Version                      0
# Price                      291
# Currency                     0
# Free                         0
# DeveloperId                  0
# Developer                    0
# Developer_Url                0
# Developer_Website            0
# Average_User_Rating          0
# Reviews                      0
# Current_Version_Score        0
# Current_Version_Reviews      0
# Size_Mb                    170
# dtype: int64

# %% [markdown]
# ---
# OBSERVATION:
# NOW IMPUTE THE MISSING VALUES IN `SIZE_BYTES`  `SIZE_MB`  AND `PRICE COLUMN`
# ---

# %% [markdown]
# `4.1`.` *FILL THE MISSING VALUE BY MEDIAN MTHOD*

# %%
df['Price'].fillna(df['Price'].median(), inplace=True)
df['Size_Bytes'].fillna(df['Size_Bytes'].median(), inplace=True)
df['Size_Mb'].fillna(df['Size_Mb'].median(), inplace=True)

# %%
(df.isnull().sum()/len(df)*100).sort_values(ascending=False)
# Out:
# App_Id                     0.0
# App_Name                   0.0
# Current_Version_Reviews    0.0
# Current_Version_Score      0.0
# Reviews                    0.0
# Average_User_Rating        0.0
# Developer_Website          0.0
# Developer_Url              0.0
# Developer                  0.0
# DeveloperId                0.0
# Free                       0.0
# Currency                   0.0
# Price                      0.0
# Version                    0.0
# Updated                    0.0
# Released                   0.0
# Required_IOS_Version       0.0
# Size_Bytes                 0.0
# Content_Rating             0.0
# Primary_Genre              0.0
# AppStore_Url               0.0
# Size_Mb                    0.0
# dtype: float64

# %% [markdown]
# ---
# ## 4 **Duplicates**
#
# * Removing duplicates is one of the most important part of the data wrangling process, we must remove the duplicates in order to get the correct insights from the data.
# * If you do not remove duplicates from a dataset, it can lead to incorrect insights and analysis.
# * Duplicates can skew statistical measures such as mean, median, and standard deviation, and can also lead to over-representation of certain data points.
# * It is important to remove duplicates to ensure the accuracy and reliability of your data analysis.

# %% [markdown]
#  # `4.1` *NOW CHECK THE DUPLICATE VALUES*

# %%
duplicate_rows=df[df.duplicated()]

# %% [markdown]
# ---
# #  NO DUPICATE VALUES FOUND WE ARE GOOD TO GO

# %% [markdown]
# # `4.2`:lets change the content rating that every one understand it

# %%
for i in df.Content_Rating.unique():
    print(i)
# Out:
# 4+
# 17+
# 9+
# 12+
# Not yet rated

# %%
df["Content_Rating"]=df["Content_Rating"].replace("4+","Children")
df["Content_Rating"]=df["Content_Rating"].replace("9+","Children")
df["Content_Rating"]=df["Content_Rating"].replace("12+","Teens")
df["Content_Rating"]=df["Content_Rating"].replace("17+","Adults")
df["Content_Rating"]=df["Content_Rating"].replace("Not yet rated","Everyone")

# %%
df.head(5)
# Out:
#                               App_Id                        App_Name  \
# 4   com.imonstersoft.azdictionaryios         A-Z Synonyms Dictionary
# 7   BestPracticeSystems.IOSAppUpload          A19BestPracticeSystems
# 9                    com.aaaakh.news                         A4 News
# 11        com.goodbarber.bigbookfree        AA Big Book (Unofficial)
# 13            com.aabigbook.appstore  AA Big Book App  -  Unofficial
#
#                                          AppStore_Url Primary_Genre  \
# 4   https://apps.apple.com/us/app/a-z-synonyms-dic...     Reference
# 7   https://apps.apple.com/us/app/a19bestpractices...          Book
# 9   https://apps.apple.com/us/app/a4-news/id145538...          News
# 11  https://apps.apple.com/us/app/aa-big-book-unof...          Book
# 13  https://apps.apple.com/us/app/aa-big-book-app-...          Book
#
#    Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# ...

# %% [markdown]
# #
# `now content rating is changed`

# %% [markdown]
# ---
# # `obesrvation`:why not we change  'usd' CURRENCY to 'dollar' so lets do it

# %%
for i in df.Currency.unique():
    print(i)
# Out:
# USD

# %%
df["Currency"]=df["Currency"].replace("USD","DOLLAR")

# %%
df.head(5)
# Out:
#                               App_Id                        App_Name  \
# 4   com.imonstersoft.azdictionaryios         A-Z Synonyms Dictionary
# 7   BestPracticeSystems.IOSAppUpload          A19BestPracticeSystems
# 9                    com.aaaakh.news                         A4 News
# 11        com.goodbarber.bigbookfree        AA Big Book (Unofficial)
# 13            com.aabigbook.appstore  AA Big Book App  -  Unofficial
#
#                                          AppStore_Url Primary_Genre  \
# 4   https://apps.apple.com/us/app/a-z-synonyms-dic...     Reference
# 7   https://apps.apple.com/us/app/a19bestpractices...          Book
# 9   https://apps.apple.com/us/app/a4-news/id145538...          News
# 11  https://apps.apple.com/us/app/aa-big-book-unof...          Book
# 13  https://apps.apple.com/us/app/aa-big-book-app-...          Book
#
#    Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# ...

# %% [markdown]
# # `4.3` lets change the price make it in concise foam that everyone can understand

# %% [markdown]
# ---

# %%
def categorize_price(price):
    if price == 0:
        return 'Free'
    elif price < 5:
        return 'Cheap'
    elif price < 20:
        return 'Moderate'
    else:
        return 'Expensive'

df['Price_Band'] = df['Price'].apply(categorize_price)

# %%
df['Price_Band'].value_counts()
# Out:
# Price_Band
# Free         528308
# Cheap         43703
# Moderate      11002
# Expensive      2999
# Name: count, dtype: int64

# %% [markdown]
# # `4.4`:*Let's change the Reviews to certain ranges for the better understanding of the data*

# %%
df['Reviews'].min()
# Out:
# 0

# %%
df['Reviews'].max()
# Out:
# 22685334

# %% [markdown]
# ---
# `Observation` :
# - Review column is numeric column that holds information about the number fo reviews users left while dowloading /using the app
#
# - We have a long sequence of data when it comes to Reviews column :
#
# min 0 max 22685334
#
# - We can club this long sequence into a compressed form and presentation. In another column called ReviewCategory
#
# - if an app has reviews between 0 and 10000 --> Less than 10K
# - if an app has reviews between 10000 and 500000 --> Between 10K and 500K
# - if an app has reviews between 500000 and 1000000 --> Between 500K and 1Mil
# - if an app has reviews between 1000000 and 22685334 --> Million Plus

# %%
df.Reviews.describe()
# Out:
# count    5.860120e+05
# mean     1.556344e+03
# std      7.174657e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      5.000000e+00
# max      2.268533e+07
# Name: Reviews, dtype: float64

# %%
df['ReviewCategory'] = 'NoReviewsProvided'
df.loc[(df['Reviews'] > 0) & (df['Reviews'] <= 10000.0),'ReviewCategory'] = 'Less than 10K'
df.loc[(df['Reviews'] > 10000) & (df['Reviews'] <= 500000.0),'ReviewCategory'] = 'Between 10K and 500K'
df.loc[(df['Reviews'] > 500000) & (df['Reviews'] <= 1000000),'ReviewCategory'] = 'Between 500K and 1Mil'
df.loc[(df['Reviews'] > 1000000) & (df['Reviews'] <= 22685334),'ReviewCategory'] = 'Million Plus'
df['ReviewCategory'].value_counts()
# Out:
# ReviewCategory
# NoReviewsProvided        299663
# Less than 10K            280487
# Between 10K and 500K       5586
# Million Plus                139
# Between 500K and 1Mil       137
# Name: count, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # `4.5`:  Insights from Data

# %% [markdown]
# ---

# %% [markdown]
# # `1` Analysis of App Release Trends Over Time

# %%
df['Released_Year'] = pd.to_datetime(df['Released']).dt.year
release_trend = df['Released_Year'].value_counts().sort_index()

plt.figure(figsize=(14, 6))
sns.lineplot(x=release_trend.index, y=release_trend.values, marker='o')
plt.title('Number of Apps Released Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Apps')
plt.grid(True)
plt.show()

# %% [markdown]
#  `Explanation`:
#  ***This line plot will highlight the growth or decline in the number of apps released per year, providing insights into the popularity of app development over time***.

# %% [markdown]
# `2` ***Correlation Analysis Between Price and User Rating***

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Price', y='Average_User_Rating', data=df)
plt.title('Correlation Between Price and User Rating')
plt.xlabel('Price')
plt.ylabel('User Rating')
plt.grid(True)
plt.show()

# %% [markdown]
# - `Explanation`:
# ***This scatter plot will visualize whether there's any significant relationship between how much users pay for an app and how they rate it**
# ---

# %% [markdown]
# # `3` *App Ratings Across Different Price*

# %%
plt.figure(figsize=(14, 6))
sns.boxplot(x='Price_Band', y='Average_User_Rating', data=df, palette='Set2')
plt.title('App Ratings Across Different Price Tiers')
plt.xlabel('Price Band')
plt.ylabel('Average User Rating')
plt.show()

# %% [markdown]
# # `Explanation`:
# ***This boxplot shows how app ratings vary across different price , revealing whether higher-priced apps receive better or worse ratings.***

# %% [markdown]
# ---
# # `4` *Revenue Estimation Based on Price and Downloads*

# %%
df['Estimated_Revenue'] = df['Price'] * df['Reviews']
revenue_by_genre = df.groupby('Primary_Genre')['Estimated_Revenue'].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
sns.barplot(x=revenue_by_genre.index, y=revenue_by_genre.values)
plt.xticks(rotation=90)
plt.title('Estimated Revenue by Genre')
plt.xlabel('Genre')
plt.ylabel('Estimated Revenue')
plt.grid(True)
plt.show()

# %% [markdown]
# # `Explanation`:
# ***This bar plot will rank genres by estimated revenue, providing insight into which types of apps are the most financially successful***.

# %% [markdown]
# ---
# # `5`. Yearly Comparison of Average App Size

# %%
avg_size_per_year = df.groupby('Released_Year')['Size_Mb'].mean()

plt.figure(figsize=(14, 6))
sns.lineplot(x=avg_size_per_year.index, y=avg_size_per_year.values, marker='o')
plt.title('Average App Size Over the Years')
plt.xlabel('Year')
plt.ylabel('Average Size (MB)')
plt.grid(True)
plt.show()

# %% [markdown]
# # `Explanation`:
# ***This line plot will reveal trends in the average app size over the years, indicating if modern apps tend to be larger or more data-intensive than those in the past***

# %% [markdown]
# ---
# # `6`. Price Distribution by Content Rating

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Content_Rating', y='Price', data=df)
plt.title('Price Distribution by Content Rating')
plt.xlabel('Content Rating')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %% [markdown]
# # `Explanation`:
# ***This box plot will reveal pricing strategies across different content ratings, helping to identify if apps targeted at certain age groups are generally more expensive***

# %% [markdown]
# ---

# %% [markdown]
# # `7`-*Top 5 Genres with Highest Total Reviews*

# %%
top_genres_reviews = df.groupby('Primary_Genre')['Reviews'].sum().sort_values(ascending=False).head(5)
top_genres_reviews.plot(kind='bar', figsize=(10, 6))
plt.title('Top 5 Genres with Highest Total Reviews')
plt.ylabel('Total Reviews')
plt.show()

# %% [markdown]
# # `Explanation`:
# ***The plot will help identify which genres are the most popular based on user reviews***

# %% [markdown]
# ---

# %% [markdown]
# # `8`. Size vs. Price

# %%
paid_apps = df[df['Free'] == 0]  # Filter out free apps
plt.figure(figsize=(10, 6))
plt.scatter(paid_apps['Size_Mb'], paid_apps['Price'], alpha=0.5)
plt.title('Size vs. Price for Paid Apps')
plt.xlabel('Size (MB)')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# # `Explanation`:
# ***This plot helps you visually assess whether there is any correlation between the size of the app and its price. For example, you might look for patterns to see if larger apps tend to be more expensive or if there is no clear relationship between size and price***

# %% [markdown]
# ---

# %% [markdown]
# # 9 Genre Diversity Among Top-Rated Apps

# %%
top_rated_genres = df[df['Average_User_Rating'] >= 4.5]['Primary_Genre'].value_counts()
plt.figure(figsize=(10, 6))
top_rated_genres.plot(kind='bar', color='coral')
plt.title('Genre Diversity Among Top-Rated Apps')
plt.xlabel('Genre')
plt.ylabel('Number of Apps')
plt.show()

# %% [markdown]
# Eexplanation:
# *Analyze how diverse the genres are among apps with the highest ratings.*

# %% [markdown]
#  # 10 Monthly App Release Trends

# %%
df['Release_Month'] = pd.to_datetime(df['Released']).dt.month
monthly_trends = df['Release_Month'].value_counts().sort_index()
plt.figure(figsize=(10, 6))
monthly_trends.plot(kind='bar', color='teal')
plt.title('Number of Apps Released by Month')
plt.xlabel('Month')
plt.ylabel('Number of Apps')
plt.grid(True)
plt.show()

# %% [markdown]
#  # 11 Top 10 Most Expensive Apps

# %%
top_10_expensive = df.nlargest(10, 'Price')[['App_Name', 'Price', 'Average_User_Rating', 'Reviews']]
plt.figure(figsize=(14, 7))
sns.barplot(x='Price', y='App_Name', data=top_10_expensive, palette='Reds')
plt.title('Top 10 Most Expensive Apps')
plt.xlabel('Price ($)')
plt.ylabel('App Name')
plt.show()
